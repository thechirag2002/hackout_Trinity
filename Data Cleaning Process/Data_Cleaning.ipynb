# %% [markdown]
# ### import essential Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Reading CSV file and converting it into python DataFrame using "pandas"

# %%
travelData=pd.DataFrame(pd.read_excel('Travel_SQL.xlsx'))
travelData
# Out:
#                 Destination  Duration_days    Traveler_name  Traveler_age  \
# 0                London, UK            7.0       John Smith          35.0
# 1          Phuket, Thailand            5.0         Jane Doe          28.0
# 2           Bali, Indonesia            7.0        David Lee          45.0
# 3             New York, USA           14.0    Sarah Johnson          29.0
# 4              Tokyo, Japan            7.0       Kim Nguyen          26.0
# ..                      ...            ...              ...           ...
# 138  Rio de Janeiro, Brazil            9.0       Jose Perez          37.0
# 139       Vancouver, Canada            6.0      Emma Wilson          29.0
# 140       Bangkok, Thailand            7.0        Ryan Chen          34.0
# 141        Barcelona, Spain            7.0  Sofia Rodriguez          25.0
# 142   Auckland, New Zealand            7.0    William Brown          39.0
#
#     Traveler_gender Traveler_nationality Accommodation_type  \
# ...

# %% [markdown]
# ### Cleaning Data
#
# - Removing irrelevant data
# - Removing NULL Tuples
# - Replacing NULL values with mean value of the column
# - Removing Duplicate values

# %% [markdown]
# #### Removing irrelevant data

# %%
travelData.drop(['Traveler_name'], axis=1, inplace=True)
travelData
# Out:
#                 Destination  Duration_days  Traveler_age Traveler_gender  \
# 0                London, UK            7.0          35.0            Male
# 1          Phuket, Thailand            5.0          28.0          Female
# 2           Bali, Indonesia            7.0          45.0            Male
# 3             New York, USA           14.0          29.0          Female
# 4              Tokyo, Japan            7.0          26.0          Female
# ..                      ...            ...           ...             ...
# 138  Rio de Janeiro, Brazil            9.0          37.0            Male
# 139       Vancouver, Canada            6.0          29.0          Female
# 140       Bangkok, Thailand            7.0          34.0            Male
# 141        Barcelona, Spain            7.0          25.0          Female
# 142   Auckland, New Zealand            7.0          39.0            Male
#
#     Traveler_nationality Accommodation_type  Accommodation_cost  \
# ...

# %%
travelData.dropna(axis=0, inplace=True)
travelData
# Out:
#                 Destination  Duration_days  Traveler_age Traveler_gender  \
# 0                London, UK            7.0          35.0            Male
# 1          Phuket, Thailand            5.0          28.0          Female
# 2           Bali, Indonesia            7.0          45.0            Male
# 3             New York, USA           14.0          29.0          Female
# 4              Tokyo, Japan            7.0          26.0          Female
# ..                      ...            ...           ...             ...
# 138  Rio de Janeiro, Brazil            9.0          37.0            Male
# 139       Vancouver, Canada            6.0          29.0          Female
# 140       Bangkok, Thailand            7.0          34.0            Male
# 141        Barcelona, Spain            7.0          25.0          Female
# 142   Auckland, New Zealand            7.0          39.0            Male
#
#     Traveler_nationality Accommodation_type  Accommodation_cost  \
# ...

# %%
travelData = travelData.drop_duplicates()
travelData
# Out:
#                 Destination  Duration_days  Traveler_age Traveler_gender  \
# 0                London, UK            7.0          35.0            Male
# 1          Phuket, Thailand            5.0          28.0          Female
# 2           Bali, Indonesia            7.0          45.0            Male
# 3             New York, USA           14.0          29.0          Female
# 4              Tokyo, Japan            7.0          26.0          Female
# ..                      ...            ...           ...             ...
# 138  Rio de Janeiro, Brazil            9.0          37.0            Male
# 139       Vancouver, Canada            6.0          29.0          Female
# 140       Bangkok, Thailand            7.0          34.0            Male
# 141        Barcelona, Spain            7.0          25.0          Female
# 142   Auckland, New Zealand            7.0          39.0            Male
#
#     Traveler_nationality Accommodation_type  Accommodation_cost  \
# ...

# %% [markdown]
# #### The necessary data preprocessing has been meticulously executed, affirming that the data has been impeccably cleansed and is now primed for analysis and other applications.
