# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_excel('Visualization_data.xlsx')
data
# Out:
#      Unnamed: 0     Destination  Duration_days  Traveler_age Traveler_gender  \
# 0             0          London              7            35            Male
# 1             1          Phuket              5            28          Female
# 2             2            Bali              7            45            Male
# 3             3        New York             14            29          Female
# 4             4           Tokyo              7            26          Female
# ..          ...             ...            ...           ...             ...
# 131         131  Rio de Janeiro              9            37            Male
# 132         132       Vancouver              6            29          Female
# 133         133         Bangkok              7            34            Male
# 134         134       Barcelona              7            25          Female
# 135         135        Auckland              7            39            Male
#
# ...

# %%
data_new=data[['Destination','travel_start']].copy()
data_new
# Out:
#         Destination  travel_start
# 0            London             1
# 1            Phuket             6
# 2              Bali             1
# 3          New York             8
# 4             Tokyo            10
# ..              ...           ...
# 131  Rio de Janeiro             1
# 132       Vancouver             8
# 133         Bangkok             1
# 134       Barcelona             9
# 135        Auckland             1
#
# [136 rows x 2 columns]

# %%
from matplotlib import pyplot as plt
data_new['travel_start'].plot(kind='hist', bins=20, title='travel_start')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### Pie Chart

# %%
destination=[
    "Amsterdam", "Athens", "Auckland", "Australia", "Bali","Bangkok",
    "Barcelona","Berlin", "Brazil", "Canada", "Cancun",
    "Cape Town","Dubai","Edinburgh", "Egypt", "France", "Greece", "Hawaii", "Honolulu", "Italy",
    "Japan", "London","Los Angeles", "Marrakech", "Mexico", "New York","New York City","Paris","Phnom Penh", "Phuket","Rio de Janeiro",
    "Rome",
    "Santorini", "Seoul","Spain", "Sydney","Thailand", "Tokyo",
    "Vancouver",
]
Count=[3, 1, 1, 1, 11, 8, 6, 1, 1, 1, 4, 4, 3, 1, 1, 1, 1, 1, 1, 1, 1, 7, 1, 1, 1, 8, 2, 13, 1, 3, 5, 8, 1, 2, 1, 12, 1, 12, 2]
fig = plt.figure(figsize =(10, 15))
plt.pie(Count, labels = destination)

# show plot
plt.show()

# %%
data_new2=data[['Destination','Accommodation_cost']].copy()
data_new2
# Out:
#         Destination  Accommodation_cost
# 0            London                1200
# 1            Phuket                 800
# 2              Bali                1000
# 3          New York                2000
# 4             Tokyo                 700
# ..              ...                 ...
# 131  Rio de Janeiro                2500
# 132       Vancouver                5000
# 133         Bangkok                2000
# 134       Barcelona                6000
# 135        Auckland                7000
#
# [136 rows x 2 columns]

# %%
x = data_new2['Destination']
y = data_new2['Accommodation_cost']

fig = plt.figure(figsize=(30,12))

plt.stem(x, y)
plt.show()
